# %%
import pandas as pd
import seaborn as sns

# %%
df2= pd.read_csv("Automobile.csv")

# %%
df2.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df2.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
sns.relplot(x="engine_size", y="horsepower", data=df2)

# %%
sns.relplot(x="engine_size", y="horsepower", hue= "fuel_type", data=df2)

# %%
sns.relplot(x="engine_size", y="horsepower", hue= "peak_rpm", data=df2)

# %%
sns.relplot(x="engine_size", y="horsepower", size= "peak_rpm", data=df2)

# %%
sns.relplot(x="engine_size", y="horsepower", hue = "peak_rpm", size= "peak_rpm", data=df2)

# %%
sns.catplot(x="make", y="price", data=df2, aspect=4)

# %%
sns.catplot(x="make", y="price",hue="number_of_doors", data=df2, aspect=4)

# %%
sns.catplot(x="make", y="body_style", data=df2, aspect=4)

# %%
sns.catplot(x="make", y="body_style",hue="number_of_doors", data=df2, aspect=4)

# %%
sns.catplot(x="fuel_type", y="price", data=df2)

# %%
sns.catplot(x="body_style", y="price", data=df2)

# %%
sns.catplot(x="body_style", y="price", data=df2, jitter=False)

# %%
sns.catplot(x="body_style", y="price", hue="fuel_type",data=df2)

# %%
sns.catplot(x="body_style", y="price", hue="aspiration",data=df2)

# %%
sns.catplot(x="body_style", y="price", hue="number_of_doors",data=df2)

# %%
sns.catplot(x="body_style", y="price", hue="drive_wheels",data=df2)

# %%
sns.catplot(x="body_style", y="price", hue="fuel_system",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind ="box",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind="box", hue="fuel_type",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind="box", hue="aspiration",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind="box", hue="number_of_doors",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind= "box", hue="drive_wheels",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind="box", hue="fuel_system",data=df2,aspect = 2.5)

# %%
sns.catplot(x="body_style", y="price",kind="bar",data=df2)

# %%
sns.catplot(x="body_style", y="price",kind="bar",hue="number_of_doors",data=df2)

# %%
sns.catplot(x="body_style", y="price",kind="bar",hue="fuel_type",data=df2)

# %%
sns.catplot(x="body_style", y="price",kind="violin",data=df2,aspect=2)

# %%
sns.catplot(x="body_style", y="price",kind="violin",hue="number_of_doors",data=df2,aspect=1.5)

# %%
sns.catplot(x="body_style", y="price",kind="violin",hue="number_of_doors",split=True,data=df2,aspect=1.5)

# %%
sns.catplot(x="body_style", y="price",kind="violin",hue="fuel_type",data=df2,aspect=1.5)

# %%
sns.catplot(x="body_style", y="price",kind="violin",hue="fuel_type",split= True, data=df2,aspect=1.5)

# %%
sns.catplot(x="body_style", y="price",kind="point", data=df2)

# %%
sns.catplot(x="body_style", y="price",kind="point",hue="fuel_type", data=df2)

# %%
sns.catplot(x="body_style", y="price",kind="point",hue="number_of_doors", data=df2)

# %%
sns.catplot(x="body_style", y="price", kind= "boxen",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind= "boxen",hue="number_of_doors",data=df2)

# %%
sns.catplot(x="body_style", y="price", kind= "boxen",hue="fuel_type",data=df2,aspect=2.7,height=4)

# %%
sns.histplot(df2.price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.distplot(df2.price)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.displot(df2.price)

# %%
sns.distplot(df2.price,kde=False,rug=True)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price'>

# %%
sns.displot(df2.body_style)

# %%
sns.distplot(df2.stroke)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %%
sns.displot(df2.stroke)

# %%
sns.distplot(df2.compression_ratio)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='compression_ratio', ylabel='Density'>

# %%
sns.displot(df2.compression_ratio)

# %%
sns.distplot(df2.engine_size)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='engine_size', ylabel='Density'>

# %%
sns.distplot(df2.horsepower)
# Out:
# C:\Users\Lucky\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.jointplot(x="body_style", y="price", data=df2)

# %%
sns.jointplot(x="horsepower", y="price", data=df2)

# %%
sns.jointplot(x="engine_size", y="horsepower", data=df2)

# %%
sns.jointplot(x="engine_size", y="horsepower", kind = "hex",data=df2)

# %%
a=df2.corr()
a
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.474993   -0.535987 -0.365404
# normalized_losses   0.474993           1.000000    0.007815  0.103659
# wheel_base         -0.535987           0.007815    1.000000  0.876024
# length             -0.365404           0.103659    0.876024  1.000000
# width              -0.242423           0.153752    0.814507  0.857170
# height             -0.550160          -0.335476    0.590742  0.492063
# curb_weight        -0.233118           0.178547    0.782097  0.880665
# engine_size        -0.110581           0.174788    0.572027  0.685025
# bore               -0.146355           0.007498    0.495210  0.610324
# stroke              0.018373           0.062666    0.148239  0.116745
# compression_ratio  -0.182196          -0.120846    0.250313  0.159733
# horsepower          0.075287           0.276665    0.372607  0.577923
# ...

# %%
sns.heatmap(a,annot=True)
# Out:
# <AxesSubplot:>
